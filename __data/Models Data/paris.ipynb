# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
df = pd.read_csv("data/synthetic_data.csv", index_col=0)

# %%
df_2 = pd.read_csv("data/Survey _Rutas.csv", index_col=0)

# %%
df_2
# Out:
#           Género ¿De cuánto tiempo dispones para realizar la ruta?  \
# Edad\r\n
# 35-45     Hombre                                           3 horas
# 18-35     Hombre                                            1 hora
# 18-35     Hombre                                           2 horas
# 35-45     Hombre                                           3 horas
# 35-45     Hombre                                           4 horas
# ...          ...                                               ...
# 18-35      Mujer                                       1 - 2 horas
# 18-35      Mujer                                       1 - 2 horas
# 35-45     Hombre                                       1 - 2 horas
# 35-45      Mujer                                       3 - 4 horas
# 18-35      Mujer                                       1 - 2 horas
#
#          Tipo de ruta preferida Coste dispuesto a pagar Dificultad  \
# Edad\r\n
# 35-45                 Turistica              1-50 Euros       Alta
# 18-35                 Turistica                  Gratis       Baja
# 18-35                 Turistica                  Gratis       Baja
# 35-45                 Literaria              1-50 Euros       Alta
# 35-45                 Historica                  Gratis       Alta
# ...                         ...                     ...        ...
# 18-35                 Turistica                  Gratis       Baja
# 18-35                 Turistica                  Gratis       Baja
# 35-45                 Turistica                  Gratis       Alta
# 35-45                 Historica              1-50 Euros       Baja
# 18-35                 Literaria                  Gratis       Baja
#
#          Acompañamiento Transporte score Selecciona las rutas de tu interés  \
# Edad\r\n
# 35-45              Solo        NaN  0,05                                NaN
# 18-35              Solo        Pie  0,05                                NaN
# 18-35              Solo        Pie  0,05                                NaN
# 35-45              Solo        Pie  0,05                                NaN
# 35-45            Pareja        Pie  0,05                                NaN
# ...                 ...        ...   ...                                ...
# 18-35            Pareja      A Pie  0,07                                NaN
# 18-35            Pareja      A Pie  0,07                                NaN
# 35-45            Amigos  Bicicleta  0,05                                NaN
# 35-45           Familia  Bicicleta  0,07                                NaN
# 18-35              Solo  Bicicleta  0,07                                NaN
#
#          Selecciona la ruta a pie de dificultad alta de tu interés  \
# Edad\r\n
# 35-45                                                   NaN
# 18-35                                                   NaN
# 18-35                                                   NaN
# 35-45                                                   NaN
# 35-45                                                   NaN
# ...                                                     ...
# 18-35                                                   NaN
# 18-35                                                   NaN
# 35-45                                                   NaN
# 35-45                                                   NaN
# 18-35                                                   NaN
#
#          Selecciona la ruta a pie de dificultad baja de tu interés  \
# Edad\r\n
# 35-45                                                   NaN
# 18-35                                                   NaN
# 18-35                                                   NaN
# 35-45                                                   NaN
# 35-45                                                   NaN
# ...                                                     ...
# 18-35                           Ruta Valencia en la Memòria
# 18-35                     Arbres: Un passeig per l’Albereda
# 35-45                                                   NaN
# 35-45                                                   NaN
# 18-35                                                   NaN
#
#          Selecciona la ruta en bici de tu interés         Submitted At  \
# Edad\r\n
# 35-45                                         NaN  18/07/2022 20:59:06
# 18-35                                         NaN  18/07/2022 20:58:59
# 18-35                                         NaN  18/07/2022 20:57:28
# 35-45                                         NaN  18/07/2022 20:57:22
# 35-45                                         NaN  18/07/2022 21:55:56
# ...                                           ...                  ...
# 18-35                                         NaN  21/07/2022 20:18:38
# 18-35                                         NaN   22/07/2022 7:04:17
# 35-45                  Ruta València en bicicleta   22/07/2022 7:16:54
# 35-45              Arbres monumentals i singulars   22/07/2022 7:17:50
# 18-35              Arbres monumentals i singulars   22/07/2022 7:22:58
#
#                                      Token
# Edad\r\n
# 35-45     j1zmueljgcm6fy03r89sj1zmn5ra1ai7
# 18-35     a8c7ldqlefm5chet9na8c7lo9vil1z70
# 18-35     drmcsypaxc4q12tz48hfdrmcsp5xrakw
# 35-45     h0by3ldyhj7bd5ku3k90uh0by3lhda9s
# 35-45     521q8u947g1dxyx521qs2mdvhw01e0l5
# ...                                    ...
# 18-35     c11kk315bcu1u3mng9bcc11kw9xk5o8c
# 18-35     laybtfhq1q5q56dx59blaybt247vt8zx
# 35-45     qn7urnm4kvg3zzvgaqn7urnmf50xc0nd
# 35-45     ntti2bg1uakx6ospnqnttfpg4surt8zl
# 18-35     g33jliqzpd431tdf0gg33jliqkgwtfy6
#
# [87 rows x 14 columns]

# %%
target = df.selection_map
X = df.iloc[:,:-1]

# %%
X = pd.get_dummies(X)

# %%
X_train,X_test,y_train,y_test = train_test_split(X, target, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()

from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier(max_depth=3, random_state=42)

from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(n_estimators=500, max_leaf_nodes=16, random_state=42)

from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
estimator = DecisionTreeClassifier(max_depth=3)
ada = AdaBoostClassifier(base_estimator = estimator, n_estimators=200, learning_rate=0.5, random_state=42)

from sklearn.ensemble import GradientBoostingClassifier
gbct = GradientBoostingClassifier(max_depth=3, n_estimators=100, random_state=42)

from xgboost import XGBRFClassifier
xgb = XGBRFClassifier(random_state=42)

from lightgbm import LGBMClassifier
lgb = LGBMClassifier()

from catboost import CatBoostClassifier
cat = CatBoostClassifier(verbose=0)

# %%
models = [log, tree, forest, ada, gbct, cat, lgb, xgb]
names = ['Logistic', 'Decision Tree', 'Random Forest', 'AdaBoost', 'Gradient Boosting', 'CatBoost', 'Lightgbm', 'XGBoost']
scores = []
predictions = {}
for idx, model in enumerate(models):
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    predictions[names[idx]] = y_pred
    scores.append(accuracy_score(y_pred, y_test))
# Out:
# c:\Users\Paris\anaconda3\envs\desafio\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
names = ['Logistic', 'Decision Tree', 'Random Forest', 'AdaBoost', 'Gradient Boosting', 'CatBoost', 'Lightgbm', 'XGBoost']
pd.DataFrame(scores, index=names, columns=['Accuracy']).sort_values(by='Accuracy', ascending=False)
# Out:
#                    Accuracy
# XGBoost            0.054500
# Logistic           0.053500
# Gradient Boosting  0.053500
# Random Forest      0.052167
# AdaBoost           0.051833
# Decision Tree      0.051167
# Lightgbm           0.050333
# CatBoost           0.048833

# %%
df_feature = pd.DataFrame(cat.get_feature_importance(), index=X.columns, columns=['feature_importance']).sort_values(by='feature_importance', ascending=False)
df_feature
# Out:
#                             feature_importance
# difficulty_Alta                       5.994473
# accompaniment_Pareja                  5.472839
# route_type_Historica                  5.402150
# gender_Mujer                          4.948714
# accompaniment_Solo                    4.886606
# price_Gratis                          4.854729
# price_1-50 Euros                      4.853599
# transport_Pie                         4.833419
# time_available_3 - 4                  4.795338
# age_18-35                             4.749164
# transport_Bicicleta                   4.675223
# age_35-45                             4.627299
# time_available_1 - 2                  4.620609
# gender_Hombre                         4.219104
# route_type_Turistica                  4.179991
# time_available_7 - 8                  3.353710
# route_type_Patrimonio                 3.290384
# accompaniment_Familia                 3.195047
# transport_A Pie                       3.071136
# age_+45                               2.851867
# difficulty_Baja                       2.602218
# price_+50 Euros                       2.383977
# route_type_Literaria                  1.909519
# gender_Prefiero no decirlo            1.518601
# age_0-18                              0.984652
# accompaniment_Amigos                  0.980491
# time_available_5 - 6                  0.745140
